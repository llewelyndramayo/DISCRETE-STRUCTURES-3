# %% [markdown]
# ASSIGNMENT 1

# %% [markdown]
# Name: Llewelyn S. Dramayo
#
#
# CS 3103 (GROUP 1): Discrete Structures 3

# %% [markdown]
# $\textbf{\large{SOLUTIONS for 1}}$

# %%
import numpy as np

# Define vectors u, v, and w
u = np.array([1, -2, 4])
v = np.array([3, 5, 1])
w = np.array([2, 1, -3])

printf("Answers for Pythonic Solution")

# a. 3u - 2v
result_a = 3 * u - 2 * v
print("a. 3u - 2v:", result_a)
# b. 5u + 3v - 4w
result_b = 5 * u + 3 * v - 4 * w
print("b. 5u + 3v - 4w:", result_b)
# c. u*v, v*w, u*w
result_c_u_v = np.dot(u, v)
result_c_v_w = np.dot(v, w)
result_c_u_w = np.dot(u, w)
print("c. u*v:", result_c_u_v)
print("   v*w:", result_c_v_w)
print("   u*w:", result_c_u_w)
# d. ||u||, ||v||, ||w||
norm_u = np.linalg.norm(u)
norm_v = np.linalg.norm(v)
norm_w = np.linalg.norm(w)
print("d. ||u||:", norm_u)
print("   ||v||:", norm_v)
print("   ||w||:", norm_w)
# e. Angle between u and v (cosine similarity)
cosine_similarity_uv = np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
theta = np.arccos(cosine_similarity_uv)
print("e. Angle between u and v:", theta)
# f. Angle between v and w (cosine similarity)
cosine_similarity_vw = np.dot(v, w) / (np.linalg.norm(v) * np.linalg.norm(w))
alpha = np.arccos(cosine_similarity_vw)
print("f. Angle between v and w:", alpha)
# g. Angle between u and w (cosine similarity)
cosine_similarity_uw = np.dot(u, w) / (np.linalg.norm(u) * np.linalg.norm(w))
beta = np.arccos(cosine_similarity_uw)
print("g. Angle between u and w:", beta)
# h. Distance between u and v
distance_uv = np.linalg.norm(u - v)
print("h. d(u, v):", distance_uv)
# i. Distance between w and v
distance_wv = np.linalg.norm(w - v)
print("i. d(w, v):", distance_wv)
# j. Distance between u and w
distance_uw = np.linalg.norm(u - w)
print("j. d(u, w):", distance_uw)
# k. Projection of u onto v
projection_uv = np.dot(u, v) / np.dot(v, v) * v
print("k. proj(u, v):", projection_uv)
# l. Projection of w onto v
projection_wv = np.dot(w, v) / np.dot(v, v) * v
print("l. proj(w, v):", projection_wv)
# m. Projection of u onto w
projection_uw = np.dot(u, w) / np.dot(w, w) * w
print("m. proj(u, w):", projection_uw)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
# \begin{align*}
# a. &\quad 3\mathbf{u} - 2\mathbf{v}:\begin{bmatrix} 3\\ -16 \\ 10 \end{bmatrix} \\
# b. &\quad 5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w}: \begin{bmatrix} 6\\ 1 \\ 35 \end{bmatrix} \\
# c. &\quad u \cdot v = -3 \\
#    &\quad v \cdot w = 8 \\
#    &\quad u \cdot w = -12 \\
# d. &\quad ||\mathbf{u}||: 4.58257569495584 \\
#    &\quad ||\mathbf{v}||: 5.916079783099616 \\
#    &\quad ||\mathbf{w}||: 3.7416573867739413 \\
# e. &\quad \text{Angle between $\mathbf{u}$ and $\mathbf{v}$ (cos $\theta$): -0.11065666703449763} \\
# f. &\quad \text{Angle between $\mathbf{v}$ and $\mathbf{w}$ (cos $\alpha$): 0.36140316116210053} \\
# g. &\quad \text{Angle between $\mathbf{u}$ and $\mathbf{w}$ (cos $\beta$): -0.6998542122237653} \\
# h. &\quad d(\mathbf{u}, \mathbf{v}): 7.874007874011811 \\
# i. &\quad d(\mathbf{w}, \mathbf{v}): 5.744562646538029 \\
# j. &\quad d(\mathbf{u}, \mathbf{w}): 7.681145747868608 \\
# k. &\quad \text{Projection of $\mathbf{u}$ onto $\mathbf{v}$}: \begin{bmatrix} -0.25714286\\ -0.42857143 \\ -0.08571429 \end{bmatrix}\\
# l. &\quad \text{Projection of $\mathbf{w}$ onto $\mathbf{v}$}: \begin{bmatrix} 0.68571429\\ 1.14285714\\ 0.22857143] \end{bmatrix}\\
# m. &\quad \text{Projection of $\mathbf{u}$ onto $\mathbf{w}$}: \begin{bmatrix} -2.57142857\\ -4.28571429 \\ -0.85714286 \end{bmatrix}\\
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
# a. $3\mathbf{u} - 2\mathbf{v}$:
#
# \begin{align*}
# 3\mathbf{u} &= 3\begin{bmatrix} 1 \\ -2 \\ 4 \end{bmatrix} = \begin{bmatrix} 3 \\ -6 \\ 12 \end{bmatrix} \\
# 2\mathbf{v} &= 2\begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} = \begin{bmatrix} 6 \\ 10 \\ 2 \end{bmatrix} \\
# 3\mathbf{u} - 2\mathbf{v} &= \begin{bmatrix} 3 - 6 \\ -6 - 10 \\ 12 - 2 \end{bmatrix} = \begin{bmatrix} -3 \\ -16 \\ 10 \end{bmatrix}
# \end{align*}
#
# b. $5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w}$:
# \begin{align*}
# 5\mathbf{u} &= 5\begin{bmatrix} 1 \\ -2 \\ 4 \end{bmatrix} = \begin{bmatrix} 5 \\ -10 \\ 20 \end{bmatrix} \\
# 3\mathbf{v} &= 3\begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} = \begin{bmatrix} 9 \\ 15 \\ 3 \end{bmatrix} \\
# 4\mathbf{w} &= 4\begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} = \begin{bmatrix} 8 \\ 4 \\ -12 \end{bmatrix} \\
# 5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w} &= \begin{bmatrix} 5 + 9 - 8 \\ -10 + 15 + 4 \\ 20 + 3 + 12 \end{bmatrix} = \begin{bmatrix} 6 \\ 9 \\ 35 \end{bmatrix}
# \end{align*}
#
# c. $\mathbf{u} \cdot \mathbf{v}$, $\mathbf{v} \cdot \mathbf{w}$, $\mathbf{u} \cdot \mathbf{w}$:
# \begin{align*}
# \mathbf{u} \cdot \mathbf{v} &= \begin{bmatrix} 1 & -2 & 4 \end{bmatrix} \begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} = 3 - 10 + 4 = -3 \\
# \mathbf{v} \cdot \mathbf{w} &= \begin{bmatrix} 3 & 5 & 1 \end{bmatrix} \begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} = 6 + 5 - 3 = 8 \\
# \mathbf{u} \cdot \mathbf{w} &= \begin{bmatrix} 1 & -2 & 4 \end{bmatrix} \begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} = 2 - 2 - 12 = -12
# \end{align*}
#
# d. $ ||\mathbf{u}||, ||\mathbf{v}||, ||\mathbf{w}|| $
# \begin{align*}
# \|\mathbf{u}\| &= \sqrt{1^2 + (-2)^2 + 4^2} = \sqrt{1 + 4 + 16} = \sqrt{21} \approx 4.58257569495584 \\
# \|\mathbf{v}\| &= \sqrt{3^2 + 5^2 + 1^2} = \sqrt{9 + 25 + 1} = \sqrt{35} \approx 5.916079783099616 \\
# \|\mathbf{w}\| &= \sqrt{2^2 + 1^2 + (-3)^2} = \sqrt{4 + 1 + 9} = \sqrt{14} \approx 3.7416573867739413
# \end{align*}
#
# e. Angle between $\mathbf{u}$ and $\mathbf{v}$:
# \begin{align*}
# \cos(\theta) &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{u}\| \cdot \|\mathbf{v}\|} \\
# &= \frac{-3}{\sqrt{21} \cdot \sqrt{35}} \approx -0.11065666703449763
# \end{align*}
#
# f. Angle between $\mathbf{v}$ and $\mathbf{w}$:
# \begin{align*}
# \cos(\alpha) &= \frac{\mathbf{v} \cdot \mathbf{w}}{\|\mathbf{v}\| \cdot \|\mathbf{w}\|} \\
# &= \frac{8}{\sqrt{35} \cdot \sqrt{14}} \approx 0.36140316116210053
# \end{align*}
#
# g. Angle between $\mathbf{u}$ and $\mathbf{w}$:
# \begin{align*}
# \cos(\beta) &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{u}\| \cdot \|\mathbf{w}\|} \\
# &= \frac{-12}{\sqrt{21} \cdot \sqrt{14}} \approx -0.6998542122237653
# \end{align*}
#
# h. Distance between $\mathbf{u}$ and $\mathbf{v}$:
# \begin{align*}
# d(\mathbf{u}, \mathbf{v}) &= \|\mathbf{u} - \mathbf{v}\| \\
# &= \left\| \begin{bmatrix} 1 \\ -2 \\ 4 \end{bmatrix} - \begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} \right\| \\
# &= \left\| \begin{bmatrix} -2 \\ -7 \\ 3 \end{bmatrix} \right\| \\
# &= \sqrt{(-2)^2 + (-7)^2 + 3^2} = \sqrt{4 + 49 + 9} = \sqrt{62} \approx 7.874007874011811
# \end{align*}
#
# i. Distance between $\mathbf{w}$ and $\mathbf{v}$:
# \begin{align*}
# d(\mathbf{w}, \mathbf{v}) &= \|\mathbf{w} - \mathbf{v}\| \\
# &= \left\| \begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} - \begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} \right\| \\
# &= \left\| \begin{bmatrix} -1 \\ -4 \\ -4 \end{bmatrix} \right\| \\
# &= \sqrt{(-1)^2 + (-4)^2 + (-4)^2} = \sqrt{1 + 16 + 16} = \sqrt{33} \approx 5.744562646538029
# \end{align*}
#
# j. Distance between $\mathbf{u}$ and $\mathbf{w}$:
# \begin{align*}
# d(\mathbf{u}, \mathbf{w}) &= \|\mathbf{u} - \mathbf{w}\| \\
# &= \left\| \begin{bmatrix} 1 \\ -2 \\ 4 \end{bmatrix} - \begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} \right\| \\
# &= \left\| \begin{bmatrix} -1 \\ -3 \\ 7 \end{bmatrix} \right\| \\
# &= \sqrt{(-1)^2 + (-3)^2 + 7^2} = \sqrt{1 + 9 + 49} = \sqrt{59} \approx 7.681145747868608
# \end{align*}
#
# k. Projection of $\mathbf{u}$ onto $\mathbf{v}$:
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{v}) &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \cdot \mathbf{v} \\
# &= \frac{-3}{35} \begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} \\
# &= \begin{bmatrix} -\frac{9}{35} \\ -\frac{15}{35} \\ -\frac{3}{35} \end{bmatrix} = \begin{bmatrix} -\frac{9}{35} \\ -\frac{3}{7} \\ -\frac{3}{35} \end{bmatrix}
# \end{align*}
#
# l. Projection of $\mathbf{w}$ onto $\mathbf{v}$:
# \begin{align*}
# \text{proj}(\mathbf{w}, \mathbf{v}) &= \frac{\mathbf{w} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \cdot \mathbf{v} \\
# &= \frac{8}{35} \begin{bmatrix} 3 \\ 5 \\ 1 \end{bmatrix} \\
# &= \begin{bmatrix} \frac{24}{35} \\ \frac{40}{35} \\ \frac{8}{35} \end{bmatrix} = \begin{bmatrix} \frac{24}{35} \\ \frac{8}{7} \\ \frac{8}{35} \end{bmatrix}
# \end{align*}
#
# m. Projection of $\mathbf{u}$ onto $\mathbf{w}$:
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{w}) &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{w}\|^2} \cdot \mathbf{w} \\
# &= \frac{-12}{14} \begin{bmatrix} 2 \\ 1 \\ -3 \end{bmatrix} \\
# &= \begin{bmatrix} \frac{-24}{14} \\ \frac{-12}{14} \\ \frac{72}{14} \end{bmatrix} = \begin{bmatrix} \frac{-24}{7} \\ \frac{-12}{7} \\ \frac{36}{7} \end{bmatrix}
# \end{align*}

# %% [markdown]
# $\textbf{\large{SOLUTIONS for 2}}$

# %%
import numpy as np

# Define vectors u, v, and w
u = np.array([1, 3, -4])
v = np.array([2, 1, 5])
w = np.array([3, -2, 6])

printf("Answers for Pythonic Solution")

# a. 3u - 2v
result_a = 3 * u - 2 * v
print("a. 3u - 2v:", result_a)

# b. 5u + 3v - 4w
result_b = 5 * u + 3 * v - 4 * w
print("b. 5u + 3v - 4w:", result_b)

# c. u*v, v*w, u*w
result_c_u_v = np.dot(u, v)
result_c_v_w = np.dot(v, w)
result_c_u_w = np.dot(u, w)
print("c. u*v:", result_c_u_v)
print("   v*w:", result_c_v_w)
print("   u*w:", result_c_u_w)

# d. ||u||, ||v||, ||w||
norm_u = np.linalg.norm(u)
norm_v = np.linalg.norm(v)
norm_w = np.linalg.norm(w)
print("d. ||u||:", norm_u)
print("   ||v||:", norm_v)
print("   ||w||:", norm_w)

# e. Angle between u and v (cosine similarity)
cosine_similarity_uv = np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
theta = np.arccos(cosine_similarity_uv)
print("e. Angle between u and v:", theta)

# f. Angle between v and w (cosine similarity)
cosine_similarity_vw = np.dot(v, w) / (np.linalg.norm(v) * np.linalg.norm(w))
alpha = np.arccos(cosine_similarity_vw)
print("f. Angle between v and w:", alpha)

# g. Angle between u and w (cosine similarity)
cosine_similarity_uw = np.dot(u, w) / (np.linalg.norm(u) * np.linalg.norm(w))
beta = np.arccos(cosine_similarity_uw)
print("g. Angle between u and w:", beta)

# h. Distance between u and v
distance_uv = np.linalg.norm(u - v)
print("h. d(u, v):", distance_uv)

# i. Distance between w and v
distance_wv = np.linalg.norm(w - v)
print("i. d(w, v):", distance_wv)

# j. Distance between u and w
distance_uw = np.linalg.norm(u - w)
print("j. d(u, w):", distance_uw)

# k. Projection of u onto v
projection_uv = np.dot(u, v) / np.dot(v, v) * v
print("k. proj(u, v):", projection_uv)

# l. Projection of w onto v
projection_wv = np.dot(w, v) / np.dot(v, v) * v
print("l. proj(w, v):", projection_wv)

# m. Projection of u onto w
projection_uw = np.dot(u, w) / np.dot(w, w) * w
print("m. proj(u, w):", projection_uw)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
#
# \begin{align*}
# a. \quad & 3\mathbf{u} - 2\mathbf{v} = \begin{bmatrix} -1 \\ 7 \\ -22 \end{bmatrix} \\
# b. \quad & 5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w} = \begin{bmatrix} -1 \\ 26 \\ -29 \end{bmatrix} \\
# c. \quad & \text{Dot products:} \quad \mathbf{u} \cdot \mathbf{v} = -15 \quad \mathbf{v} \cdot \mathbf{w} = 34 \quad \mathbf{u} \cdot \mathbf{w} = -27 \\
# d. \quad & \|\mathbf{u}\| = 5.0990195135927845
#     \quad \|\mathbf{v}\| = 5.477225575051661
#     \quad \|\mathbf{w}\| = 7.0 \\
# e. \quad & \text{Angle between $\mathbf{u}$ and $\mathbf{v}$:} \quad -0.5370861555295747 \\
# f. \quad & \text{Angle between $\mathbf{v}$ and $\mathbf{w}$:} \quad 0.8867889026274118 \\
# g. \quad & \text{Angle between $\mathbf{u}$ and $\mathbf{w}$:} \quad -0.7564479498187099 \\
# h. \quad & \text{Distances:} \quad d(\mathbf{u}, \mathbf{v}) = 9.273618495495704 \quad d(\mathbf{w}, \mathbf{v}) = 3.3166247903554 \quad d(\mathbf{u}, \mathbf{w}) = 11.357816691600547 \\
# k. \quad & \text{Projections:} \quad \text{proj}(\mathbf{u}, \mathbf{v}) = \begin{bmatrix} -1 \\ -0.5 \\ -2.5 \end{bmatrix} \quad \text{proj}(\mathbf{w}, \mathbf{v}) = \begin{bmatrix} 2.26666667 \\ 1.13333333 \\ 5.66666667 \end{bmatrix} \quad \text{proj}(\mathbf{u}, \mathbf{w}) = \begin{bmatrix} -1.10204082 \\ -0.55102041 \\ -2.75510204 \end{bmatrix}
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
# a. $ 3\mathbf{u} - 2\mathbf{v}\:$
# \begin{align*}
# 3\mathbf{u} &= 3 \begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} = \begin{bmatrix} 3 \\ 9 \\ -12 \end{bmatrix} \\
# 2\mathbf{v} &= 2 \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} = \begin{bmatrix} 4 \\ 2 \\ 10 \end{bmatrix} \\
# 3\mathbf{u} - 2\mathbf{v} &= \begin{bmatrix} 3 \\ 9 \\ -12 \end{bmatrix} - \begin{bmatrix} 4 \\ 2 \\ 10 \end{bmatrix} = \begin{bmatrix} -1 \\ 7 \\ -22 \end{bmatrix}
# \end{align*}
#
# b. $ 5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w}\:$
# \begin{align*}
# 5\mathbf{u} &= 5 \begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} = \begin{bmatrix} 5 \\ 15 \\ -20 \end{bmatrix} \\
# 3\mathbf{v} &= 3 \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} = \begin{bmatrix} 6 \\ 3 \\ 15 \end{bmatrix} \\
# 4\mathbf{w} &= 4 \begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix} = \begin{bmatrix} 12 \\ -8 \\ 24 \end{bmatrix} \\
# 5\mathbf{u} + 3\mathbf{v} - 4\mathbf{w} &= \begin{bmatrix} 5 \\ 15 \\ -20 \end{bmatrix} + \begin{bmatrix} 6 \\ 3 \\ 15 \end{bmatrix} - \begin{bmatrix} 12 \\ -8 \\ 24 \end{bmatrix} = \begin{bmatrix} -1 \\ 26 \\ -29 \end{bmatrix}
# \end{align*}
#
# c. $\mathbf{u} \cdot \mathbf{v}$, $\mathbf{v} \cdot \mathbf{w}$, $\mathbf{u} \cdot \mathbf{w}$:
# \begin{align*}
# \mathbf{u} \cdot \mathbf{v} &= \begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} \cdot \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} = (1 \cdot 2) + (3 \cdot 1) + (-4 \cdot 5) = 2 + 3 - 20 = -15 \\
# \mathbf{v} \cdot \mathbf{w} &= \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} \cdot \begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix} = (2 \cdot 3) + (1 \cdot -2) + (5 \cdot 6) = 6 - 2 + 30 = 34 \\
# \mathbf{u} \cdot \mathbf{w} &= \begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} \cdot \begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix} = (1 \cdot 3) + (3 \cdot -2) + (-4 \cdot 6) = 3 - 6 - 24 = -27
# \end{align*}
#
# d. $\|\mathbf{u}\|$, $\|\mathbf{v}\|$, $\|\mathbf{w}\|$:
# \begin{align*}
# \|\mathbf{u}\| &= \sqrt{1^2 + 3^2 + (-4)^2} = \sqrt{1 + 9 + 16} = \sqrt{26} \approx 5.099 \\
# \|\mathbf{v}\| &= \sqrt{2^2 + 1^2 + 5^2} = \sqrt{4 + 1 + 25} = \sqrt{30} \approx 5.477 \\
# \|\mathbf{w}\| &= \sqrt{3^2 + (-2)^2 + 6^2} = \sqrt{9 + 4 + 36} = \sqrt{49} = 7.0
# \end{align*}
#
# e. Angle between $\mathbf{u}$ and $\mathbf{v}$:
# \begin{align*}
# \cos(\theta) &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{u}\| \|\mathbf{v}\|} = \frac{-15}{5.099 \cdot 5.477} \approx -0.537 \\
# \theta &\approx \arccos(-0.537) \approx 2.176 \text{ radians (or approximately 124.5 degrees)}
# \end{align*}
#
# f. Angle between $\mathbf{v}$ and $\mathbf{w}$:
# \begin{align*}
# \cos(\alpha) &= \frac{\mathbf{v} \cdot \mathbf{w}}{\|\mathbf{v}\| \|\mathbf{w}\|} = \frac{34}{5.477 \cdot 7.0} \approx 0.886 \\
# \alpha &\approx \arccos(0.886) \approx 0.468 \text{ radians (or approximately 26.8 degrees)}
# \end{align*}
#
# g. Angle between $\mathbf{u}$ and $\mathbf{w}$:
# \begin{align*}
# \cos(\beta) &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{u}\| \|\mathbf{w}\|} = \frac{-27}{5.099 \cdot 7.0} \approx -0.757 \\
# \beta &\approx \arccos(-0.757) \approx 2.425 \text{ radians (or approximately 139.1 degrees)}
# \end{align*}
#
# h. Distance between $\mathbf{u}$ and $\mathbf{v}$ ($d(\mathbf{u}, \mathbf{v})$):
# \begin{align*}
# d(\mathbf{u}, \mathbf{v}) &= \|\mathbf{u} - \mathbf{v}\| \\
# &= \|\begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} - \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix}\| \\
# &= \|\begin{bmatrix} -1 \\ 2 \\ -9 \end{bmatrix}\| \\
# &= \sqrt{(-1)^2 + 2^2 + (-9)^2} \\
# &= \sqrt{1 + 4 + 81} \\
# &\approx 9.274
# \end{align*}
#
# i. Distance between $\mathbf{w}$ and $\mathbf{v}$ ($d(\mathbf{w}, \mathbf{v})$):
# \begin{align*}
# d(\mathbf{w}, \mathbf{v}) &= \|\mathbf{w} - \mathbf{v}\| \\
# &= \|\begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix} - \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix}\| \\
# &= \|\begin{bmatrix} 1 \\ -3 \\ 1 \end{bmatrix}\| \\
# &= \sqrt{1^2 + (-3)^2 + 1^2} \\
# &= \sqrt{1 + 9 + 1} \\
# &\approx 3.317
# \end{align*}
#
# j. Distance between $\mathbf{u}$ and $\mathbf{w}$ ($d(\mathbf{u}, \mathbf{w})$):
# \begin{align*}
# d(\mathbf{u}, \mathbf{w}) &= \|\mathbf{u} - \mathbf{w}\| \\
# &= \|\begin{bmatrix} 1 \\ 3 \\ -4 \end{bmatrix} - \begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix}\| \\
# &= \|\begin{bmatrix} -2 \\ 5 \\ -10 \end{bmatrix}\| \\
# &= \sqrt{(-2)^2 + 5^2 + (-10)^2} \\
# &= \sqrt{4 + 25 + 100} \\
# &\approx 11.358
# \end{align*}
#
# k. Projection of $\mathbf{u}$ onto $\mathbf{v}$ ($\text{proj}(\mathbf{u}, \mathbf{v})$):
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{v}) &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \mathbf{v} \\
# &= \frac{-15}{30} \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} \\
# &= \begin{bmatrix} -0.5 \\ -0.25 \\ -1.25 \end{bmatrix}
# \end{align*}
#
# l. Projection of $\mathbf{w}$ onto $\mathbf{v}$ ($\text{proj}(\mathbf{w}, \mathbf{v})$):
# \begin{align*}
# \text{proj}(\mathbf{w}, \mathbf{v}) &= \frac{\mathbf{w} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \mathbf{v} \\
# &= \frac{34}{30} \begin{bmatrix} 2 \\ 1 \\ 5 \end{bmatrix} \\
# &= \begin{bmatrix} 2.267 \\ 1.133 \\ 5.667 \end{bmatrix}
# \end{align*}
#
# m. Projection of $\mathbf{u}$ onto $\mathbf{w}$ ($\text{proj}(\mathbf{u}, \mathbf{w})$):
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{w}) &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{w}\|^2} \mathbf{w} \\
# &= \frac{-27}{49} \begin{bmatrix} 3 \\ -2 \\ 6 \end{bmatrix} \\
# &= \begin{bmatrix} -1.102 \\ -0.551 \\ -2.755 \end{bmatrix}
# \end{align*}

# %%
$\textbf{\large{SOLUTIONS for 3}}$

# %%
import numpy as np

# Define vectors u, v, and w
u = np.array([2, -5, 4, 6, -3])
v = np.array([5, -2, 1, -7, -4])
w = np.array([2, 1, -3])

printf("Answers for Pythonic Solution")

# a. 4u - 3v
result_a = 4 * u - 3 * v
print("a. 4u - 3v:", result_a)

# b. 5u + 2v - 2w
result_b = 5 * u + 2 * v - 2 * w
print("b. 5u + 2v - 2w:", result_b)

# c. u*v, v*w, u*w
result_c_u_v = np.dot(u, v)
result_c_v_w = np.dot(v, w)
result_c_u_w = np.dot(u, w)
print("c. u*v:", result_c_u_v)
print("   v*w:", result_c_v_w)
print("   u*w:", result_c_u_w)

# d. ||u||, ||v||, ||w||
norm_u = np.linalg.norm(u)
norm_v = np.linalg.norm(v)
norm_w = np.linalg.norm(w)
print("d. ||u||:", norm_u)
print("   ||v||:", norm_v)
print("   ||w||:", norm_w)

# e. Angle between u and v (cosine similarity)
cosine_similarity_uv = np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
theta = np.arccos(cosine_similarity_uv)
print("e. Angle between u and v:", theta)

# f. Angle between v and w (cosine similarity)
cosine_similarity_vw = np.dot(v, w) / (np.linalg.norm(v) * np.linalg.norm(w))
alpha = np.arccos(cosine_similarity_vw)
print("f. Angle between v and w:", alpha)

# g. Angle between u and w (cosine similarity)
cosine_similarity_uw = np.dot(u, w) / (np.linalg.norm(u) * np.linalg.norm(w))
beta = np.arccos(cosine_similarity_uw)
print("g. Angle between u and w:", beta)

# h. Distance between u and v
distance_uv = np.linalg.norm(u - v)
print("h. d(u, v):", distance_uv)

# i. Distance between w and v
distance_wv = np.linalg.norm(w - v)
print("i. d(w, v):", distance_wv)

# j. Distance between u and w
distance_uw = np.linalg.norm(u - w)
print("j. d(u, w):", distance_uw)

# k. Projection of u onto v
projection_uv = np.dot(u, v) / np.dot(v, v) * v
print("k. proj(u, v):", projection_uv)

# l. Projection of w onto v
projection_wv = np.dot(w, v) / np.dot(v, v) * v
print("l. proj(w, v):", projection_wv)

# m. Projection of u onto w
projection_uw = np.dot(u, w) / np.dot(w, w) * w
print("m. proj(u, w):", projection_uw)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
# \begin{align*}
# a. &\quad 4\mathbf{u} - 3\mathbf{v}: \begin{bmatrix}-7 \\ -14 \\ 13 \\ 45 \\ 0\end{bmatrix} \\
# b. &\quad 5\mathbf{u} + 2\mathbf{v} - 2\mathbf{w}: \begin{bmatrix}16 \\ -31 \\ 28 \\ 16 \\ -23\end{bmatrix} \\
# c. &\quad \mathbf{u} \cdot \mathbf{v} = -6 \\
#    &\quad \mathbf{v} \cdot \mathbf{w} = 5 \\
#    &\quad \mathbf{u} \cdot \mathbf{w} = -13 \\
# d. &\quad ||\mathbf{u}||: 9.486832980505138 \\
#    &\quad ||\mathbf{v}||: 9.746794344808963 \\
#    &\quad ||\mathbf{w}||: 3.7416573867739413 \\
# e. &\quad \text{Angle between $\mathbf{u}$ and $\mathbf{v}$ (cos $\theta$): -0.06488856845230502} \\
# f. &\quad \text{Angle between $\mathbf{v}$ and $\mathbf{w}$ (cos $\alpha$): 0.13710212427677046} \\
# g. &\quad \text{Angle between $\mathbf{u}$ and $\mathbf{w}$ (cos $\beta$): -0.3662335103823572} \\
# h. &\quad d(\mathbf{u}, \mathbf{v}): 14.035668847618199 \\
# i. &\quad d(\mathbf{w}, \mathbf{v}): 9.9498743710662 \\
# j. &\quad d(\mathbf{u}, \mathbf{w}): 11.40175425099138 \\
# k. &\quad \text{Projection of $\mathbf{u}$ onto $\mathbf{v}$}: \begin{bmatrix}-0.31578947 \\ 0.12631579 \\ -0.06315789 \\ 0.44210526 \\ 0.25263158\end{bmatrix} \\
# l. &\quad \text{Projection of $\mathbf{w}$ onto $\mathbf{v}$}: \begin{bmatrix}0.26315789 \\ -0.10526316 \\ 0.05263158 \\ -0.36842105 \\ -0.21052632\end{bmatrix} \\
# m. &\quad \text{Projection of $\mathbf{u}$ onto $\mathbf{w}$}: \begin{bmatrix}-4.64285714 \\ 1.85714286 \\ -0.92857143 \\ 6.5 \\ 3.71428571\end{bmatrix}
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
# a. $4\mathbf{u} - 3\mathbf{v}$:
# \begin{align*}
# 4\mathbf{u} &= (8, -20, 16, 24, -12) \\
# 3\mathbf{v} &= (15, -6, 3, -21, -12) \\
# 4\mathbf{u} - 3\mathbf{v} &= (8 - 15, -20 + 6, 16 - 3, 24 + 21, -12 + 12) \\
# &= (-7, -14, 13, 45, 0)
# \end{align*}
#
# b. $5\mathbf{u} + 2\mathbf{v} - 2\mathbf{w}$:
# \begin{align*}
# 5\mathbf{u} &= (10, -25, 20, 30, -15) \\
# 2\mathbf{v} &= (10, -4, 2, -14, -8) \\
# 2\mathbf{w} &= (4, 2, -6) \\
# 5\mathbf{u} + 2\mathbf{v} - 2\mathbf{w} &= (10 + 10 - 4, -25 - 4 + 2, 20 + 2 + 6, 30 - 14, -15 - 8) \\
# &= (16, -27, 28, 16, -23)
# \end{align*}
#
# c. Dot products:
# \begin{align*}
# \mathbf{u} \cdot \mathbf{v} &= (2 \cdot 5) + (-5 \cdot -2) + (4 \cdot 1) + (6 \cdot -7) + (-3 \cdot -4) \\
# &= 10 + 10 + 4 - 42 + 12 \\
# &= -6 \\
# \mathbf{v} \cdot \mathbf{w} &= (5 \cdot 2) + (-2 \cdot 1) + (1 \cdot -3) + (-7 \cdot 0) + (-4 \cdot -3) \\
# &= 10 - 2 - 3 + 0 + 12 \\
# &= 17 \\
# \mathbf{u} \cdot \mathbf{w} &= (2 \cdot 2) + (-5 \cdot 1) + (4 \cdot -3) + (6 \cdot 0) + (-3 \cdot -3) \\
# &= 4 - 5 - 12 + 0 + 9 \\
# &= -4
# \end{align*}
#
# d. Magnitudes (\(||\mathbf{u}||\), \(||\mathbf{v}||\), \(||\mathbf{w}||\)):
# \begin{align*}
# \|\mathbf{u}\| &= \sqrt{2^2 + (-5)^2 + 4^2 + 6^2 + (-3)^2} \\
# &= \sqrt{4 + 25 + 16 + 36 + 9} \\
# &\approx 9.49 \\
# \|\mathbf{v}\| &= \sqrt{5^2 + (-2)^2 + 1^2 + (-7)^2 + (-4)^2} \\
# &= \sqrt{25 + 4 + 1 + 49 + 16} \\
# &\approx 9.75 \\
# \|\mathbf{w}\| &= \sqrt{2^2 + 1^2 + (-3)^2} \\
# &= \sqrt{4 + 1 + 9} \\
# &\approx 3.74
# \end{align*}
#
# e. Angle between $\mathbf{u}$ and $\mathbf{v}$ ($\cos \theta$):
# \begin{align*}
# \cos \theta &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{u}\| \|\mathbf{v}\|} \\
# &= \frac{-6}{9.49 \cdot 9.75} \\
# &\approx -0.0649
# \end{align*}
#
# f. Angle between $\mathbf{v}$ and $\mathbf{w}$ ($\cos \alpha$):
# \begin{align*}
# \cos \alpha &= \frac{\mathbf{v} \cdot \mathbf{w}}{\|\mathbf{v}\| \|\mathbf{w}\|} \\
# &= \frac{17}{9.75 \cdot 3.74} \\
# &\approx 0.459
# \end{align*}
#
# g. Angle between $\mathbf{u}$ and $\mathbf{w}$ ($\cos \beta$):
# \begin{align*}
# \cos \beta &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{u}\| \|\mathbf{w}\|} \\
# &= \frac{-4}{9.49 \cdot 3.74} \\
# &\approx -0.112
# \end{align*}
#
# h. Distance between $\mathbf{u}$ and $\mathbf{v}$ ($d(\mathbf{u}, \mathbf{v})$):
# \begin{align*}
# d(\mathbf{u}, \mathbf{v}) &= \|\mathbf{u} - \mathbf{v}\| \\
# &= \sqrt{(-3)^2 + (-3)^2 + 3^2 + 13^2 + 1^2} \\
# &= \sqrt{9 + 9 + 9 + 169 + 1} \\
# &= \sqrt{197} \\
# &\approx 14.04
# \end{align*}
#
# i. Distance between $\mathbf{w}$ and $\mathbf{v}$ ($d(\mathbf{w}, \mathbf{v})$):
# \begin{align*}
# d(\mathbf{w}, \mathbf{v}) &= \|\mathbf{w} - \mathbf{v}\| \\
# &= \sqrt{(-3)^2 + 3^2 + (-4)^2} \\
# &= \sqrt{9 + 9 + 16} \\
# &= \sqrt{34} \\
# &\approx 5.83
# \end{align*}
#
# j. Distance between $\mathbf{u}$ and $\mathbf{w}$ ($d(\mathbf{u}, \mathbf{w})$):
# \begin{align*}
# d(\mathbf{u}, \mathbf{w}) &= \|\mathbf{u} - \mathbf{w}\| \\
# &= \sqrt{0^2 + (-6)^2 + 7^2 + 6^2 + 0^2} \\
# &= \sqrt{0 + 36 + 49 + 36 + 0} \\
# &= \sqrt{121} \\
# &= 11.40
# \end{align*}
#
# k. Projection of $\mathbf{u}$ onto $\mathbf{v}$ ($\text{proj}(\mathbf{u}, \mathbf{v})$):
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{v}) &= \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \mathbf{v} \\
# &= \frac{-6}{9.75^2} (5, -2, 1, -7, -4) \\
# &= (-0.3158, 0.1263, -0.0632, 0.4421, 0.2527)
# \end{align*}
#
# l. Projection of $\mathbf{w}$ onto $\mathbf{v}$ ($\text{proj}(\mathbf{w}, \mathbf{v})$):
# \begin{align*}
# \text{proj}(\mathbf{w}, \mathbf{v}) &= \frac{\mathbf{w} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \mathbf{v} \\
# &= \frac{17}{9.75^2} (5, -2, 1, -7, -4) \\
# &= (0.2632, -0.1053, 0.0526, -0.3684, -0.2105)
# \end{align*}
#
# m. Projection of $\mathbf{u}$ onto $\mathbf{w}$ ($\text{proj}(\mathbf{u}, \mathbf{w})$):
# \begin{align*}
# \text{proj}(\mathbf{u}, \mathbf{w}) &= \frac{\mathbf{u} \cdot \mathbf{w}}{\|\mathbf{w}\|^2} \mathbf{w} \\
# &= \frac{-4}{3.74^2} (2, 1, -3) \\
# &= (-4.643, 1.857, -0.929)
# \end{align*}

# %% [markdown]
# $\textbf{\large{SOLUTIONS for 4}}$

# %%
import numpy as np

# Given vectors
u = np.array([5, -7])
v = np.array([1, 2, -2, 4])
w = np.array([1/2, -1/3, 3/4])

u_normalized = u / np.linalg.norm(u)
v_normalized = v / np.linalg.norm(v)
w_normalized = w / np.linalg.norm(w)

printf("Answers for Pythonic Solution")
print("Normalized u:", u_normalized)
print("Normalized v:", v_normalized)
print("Normalized w:", w_normalized)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
#
# \begin{align*}
#     a. \quad \text{Normalized u:} \quad & \begin{bmatrix} 0.58123819 & -0.81373347 \end{bmatrix} \\
#     b. \quad \text{Normalized v:} \quad & \begin{bmatrix} 0.2 & 0.4 & -0.4 & 0.8 \end{bmatrix} \\
#     c. \quad \text{Normalized w:} \quad & \begin{bmatrix} 0.52026598 & -0.34684399 & 0.78039897 \end{bmatrix}
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
# a. Normalized u:
# \begin{align*}
# \mathbf{u}_{\text{normalized}} &= \left(\frac{5}{\sqrt{74}}, -\frac{7}{\sqrt{74}}\right) \\
# &\approx (0.58123819,  -0.81373347)
# \end{align*}
#
# b. Normalized v:
# \begin{align*}
# \mathbf{v}_{\text{normalized}} &= \left(\frac{1}{5}, \frac{2}{5}, -\frac{2}{5}, \frac{4}{5}\right) \\
# &= (0.2,  0.4,  -0.4,  0.8)
# \end{align*}
#
# c. Normalized w:
# \begin{align*}
# \mathbf{w}_{\text{normalized}} &= \left(\frac{1/2}{\sqrt{1/4 + 1/9 + 9/16}}, -\frac{1/3}{\sqrt{1/4 + 1/9 + 9/16}}, \frac{3/4}{\sqrt{1/4 + 1/9 + 9/16}}\right) \\
# &\approx (0.52026598,  -0.34684399,  0.78039897)
# \end{align*}

# %% [markdown]
# $\textbf{\large{SOLUTIONS for 5}}$

# %%
import numpy as np

u = np.array([1, 2, -2])
v = np.array([3, -12, 4])
k = -3

norm_u = np.linalg.norm(u)
norm_v = np.linalg.norm(v)
norm_u_plus_v = np.linalg.norm(u + v)
norm_ku = np.abs(k) * np.linalg.norm(u)

printf("Answers for Pythonic Solution")
print("Norm of u:", norm_u)
print("Norm of v:", norm_v)
print("Norm of u + v:", norm_u_plus_v)
print("Norm of k * u:", norm_ku)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
# \begin{align*}
#     a. \quad & ||\mathbf{u}|| = 3.0 \\
#     b. \quad & ||\mathbf{v}|| = 13.0 \\
#     c. \quad & ||\mathbf{u} + \mathbf{v}|| \approx 10.954 \\
#     d. \quad & ||k \cdot \mathbf{u}|| = 9.0
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
# a. Norm of vector \(\mathbf{u}\):
# \begin{align*}
# ||\mathbf{u}|| &= \sqrt{1^2 + 2^2 + (-2)^2} \\
# &= \sqrt{1 + 4 + 4} \\
# &= \sqrt{9} \\
# &= 3
# \end{align*}
#
# b. Norm of vector \(\mathbf{v}\):
# \begin{align*}
# ||\mathbf{v}|| &= \sqrt{3^2 + (-12)^2 + 4^2} \\
# &= \sqrt{9 + 144 + 16} \\
# &= \sqrt{169} \\
# &= 13
# \end{align*}
#
# c. Norm of the sum of vectors \(\mathbf{u}\) and \(\mathbf{v}\):
# \begin{align*}
# ||\mathbf{u} + \mathbf{v}|| &= \sqrt{(1 + 3)^2 + (2 + (-12))^2 + ((-2) + 4)^2} \\
# &= \sqrt{16 + 100 + 4} \\
# &\approx 10.954
# \end{align*}
#
# d. Norm of the scalar multiple \(-3 \cdot \mathbf{u}\):
# \begin{align*}
# ||-3 \cdot \mathbf{u}|| &= |-3| \cdot ||\mathbf{u}|| \\
# &= 3 \cdot 3 \\
# &= 9
# \end{align*}
#
# So, the results are:
# a. \(||\mathbf{u}|| = 3\)
# b. \(||\mathbf{v}|| = 13\)
# c. \(||\mathbf{u} + \mathbf{v}|| = \sqrt{120}\)
# d. \(||-3 \cdot \mathbf{u}|| = 9\)

# %% [markdown]
# $\textbf{\large{SOLUTIONS for 6}}$

# %%
import numpy as np

u_a = np.array([3, k, -2])
v_a = np.array([6, -4, -3])
u_b = np.array([5, k, -4, 2])
v_b = np.array([1, -3, 2, 2 * k])
u_c = np.array([1, 7, k + 2, -2])
v_c = np.array([3, k, -3, k])

k_a = (u_a[0] * v_a[0] + u_a[2] * v_a[2]) / 4
k_b = (u_b[0] * v_b[0] + u_b[2] * v_b[2]) * -1
k_c = (3 - 2 * k) / 2

print("a. k =", k_a)
print("b. k =", k_b)
print("c. k =", k_c)

# %% [markdown]
# $\textbf{\large{Answers for Pythonic Solution:}}$
# \begin{align*}
#     a. \quad k &= 6.0 \\
#     b. \quad k &= 3.0 \\
#     c. \quad k &= 1.5
# \end{align*}

# %% [markdown]
# $\textbf{\large{Answers for Manual Solution:}}$
#
#
# a. $\mathbf{u} = (3, k, -2)$,         $\mathbf{v} = (6, -4, -3)$:
#
# $\mathbf{u} \cdot \mathbf{v} = 3 \cdot 6 + k \cdot (-4) + (-2) \cdot (-3) $
#
#
# $\quad = 18 - 4k + 6 $
#
#
# $\quad = 24 - 4k$
#
#
# $\quad 24 - 4k = 0$
#
# Solving for $k$:
#
# $24 - 4k = 0$
#
#
# $4k = 24$
#
#
# $k = \frac{24}{4}$
#
#
# $k = 6.0$
#
#
#
# b. $\mathbf{u} = (5, k, -4, 2)$,          $\mathbf{v} = (1, -3, 2, 2k)$:
#
# $\mathbf{u} \cdot \mathbf{v} = 5 \cdot 1 + k \cdot (-3) + (-4) \cdot 2 + 2 \cdot 2k$
#
#
# $ = 5 - 3k - 8 + 4k $
#
#
# $= -3 + k$
#
#
# $-3 + k = 0$
#
# Solving for $k$:
#
#
# $k = 3.0$
#
#
#
# c. $\mathbf{u} = (1, 7, k + 2, -2)$,        $\mathbf{v} = (3, k, -3, k)$:
#
# $\mathbf{u} \cdot \mathbf{v} = 1 \cdot 3 + 7 \cdot k + (k + 2) \cdot (-3) + (-2) \cdot k$
#
#
# $ = 3 + 7k - 3k - 6 - 2k$
#
#
# $3 + 7k - 3k - 6 - 2k = 7k - 3k - 2k - 3 + 3 $
#
#
# $ = 2k - 3$
#
#
# $2k - 3 = 0$
#
# Solving for $k$:
#
# $2k = 3$
#
#
# $k = \frac{3}{2}$
#
#
# $k = 1.5$
